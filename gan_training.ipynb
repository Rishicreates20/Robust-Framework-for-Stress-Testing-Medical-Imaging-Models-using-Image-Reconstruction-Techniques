# %% [markdown]
# project/
# ├── gan_training.py          # Main script to train the GAN
# ├── generator.py             # Generator network definition
# ├── discriminator.py         # Discriminator network definition
# ├── dataset.py               # Dataset loader
# ├── metrics.py               # Metrics for evaluation (e.g., FID)
# ├── training_config.json     # Configuration for hyperparameters
# └── utils.py                 # Helper functions (e.g., gradient penalty)
#
#
# ```
# # This is formatted as code
# ```

# %%
# Install TensorFlow (if not already installed)
# !pip install tensorflow

# Import required libraries
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
import os

# Set random seed for reproducibility
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)
# Out:
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: C:\Users\rishi\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting tensorflow
#   Downloading tensorflow-2.18.0-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# Collecting tensorflow-intel==2.18.0 (from tensorflow)
#   Downloading tensorflow_intel-2.18.0-cp311-cp311-win_amd64.whl.metadata (4.9 kB)
# Collecting absl-py>=1.0.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading flatbuffers-24.12.23-py2.py3-none-any.whl.metadata (876 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in c:\users\rishi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.2)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading protobuf-5.29.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\rishi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\rishi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading termcolor-2.5.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\rishi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Collecting wrapt>=1.11.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading wrapt-1.17.0-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading grpcio-1.69.0-cp311-cp311-win_amd64.whl.metadata (4.0 kB)
# Collecting tensorboard<2.19,>=2.18 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.5.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading keras-3.8.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting numpy<2.1.0,>=1.26.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading numpy-2.0.2-cp311-cp311-win_amd64.whl.metadata (59 kB)
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/59.7 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/59.7 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/59.7 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/59.7 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/59.7 kB 119.1 kB/s eta 0:00:01
#      -------------------------- ----------- 41.0/59.7 kB 131.3 kB/s eta 0:00:01
#      -------------------------------- ----- 51.2/59.7 kB 154.6 kB/s eta 0:00:01
#      -------------------------------------- 59.7/59.7 kB 166.7 kB/s eta 0:00:00
# Collecting h5py>=3.11.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading h5py-3.12.1-cp311-cp311-win_amd64.whl.metadata (2.5 kB)
# Collecting ml-dtypes<0.5.0,>=0.4.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading ml_dtypes-0.4.1-cp311-cp311-win_amd64.whl.metadata (20 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp311-cp311-win_amd64.whl.metadata (14 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow)
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting rich (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow)
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow)
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting optree (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow)
#   Downloading optree-0.13.1-cp311-cp311-win_amd64.whl.metadata (48 kB)
#      ---------------------------------------- 0.0/48.7 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/48.7 kB ? eta -:--:--
#      ------------------------------- ------ 41.0/48.7 kB 653.6 kB/s eta 0:00:01
#      -------------------------------------- 48.7/48.7 kB 493.3 kB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rishi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rishi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rishi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rishi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.8.30)
# Collecting markdown>=2.6.8 (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow)
#   Downloading Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow)
#   Using cached MarkupSafe-3.0.2-cp311-cp311-win_amd64.whl.metadata (4.1 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rishi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.18.0-cp311-cp311-win_amd64.whl (7.5 kB)
# Downloading tensorflow_intel-2.18.0-cp311-cp311-win_amd64.whl (390.2 MB)
#    ---------------------------------------- 0.0/390.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/390.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/390.2 MB 487.6 kB/s eta 0:13:21
#    ---------------------------------------- 0.1/390.2 MB 558.5 kB/s eta 0:11:39
#    ---------------------------------------- 0.1/390.2 MB 459.5 kB/s eta 0:14:10
#    ---------------------------------------- 0.1/390.2 MB 490.2 kB/s eta 0:13:16
#    ---------------------------------------- 0.2/390.2 MB 573.4 kB/s eta 0:11:21
#    ---------------------------------------- 0.2/390.2 MB 583.1 kB/s eta 0:11:09
#    ---------------------------------------- 0.2/390.2 MB 583.1 kB/s eta 0:11:09
#    ---------------------------------------- 0.2/390.2 MB 565.6 kB/s eta 0:11:30
#    ---------------------------------------- 0.2/390.2 MB 514.3 kB/s eta 0:12:39
#    ---------------------------------------- 0.3/390.2 MB 527.8 kB/s eta 0:12:19
9 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------ --- 14.4/15.9 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------ --- 14.4/15.9 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------ --- 14.6/15.9 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------ --- 14.7/15.9 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------- -- 14.8/15.9 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------- -- 15.0/15.9 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------- -- 15.1/15.9 MB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 15.2/15.9 MB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 15.3/15.9 MB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 15.5/15.9 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.9 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  15.8/15.9 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  15.9/15.9 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  15.9/15.9 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  15.9/15.9 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 15.9/15.9 MB 2.5 MB/s eta 0:00:00
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
#    ---------------------------------------- 0.0/71.9 kB ? eta -:--:--
#    ---------------------------------------  71.7/71.9 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  71.7/71.9 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 71.9/71.9 kB 656.3 kB/s eta 0:00:00
# Downloading protobuf-5.29.3-cp310-abi3-win_amd64.whl (434 kB)
#    ---------------------------------------- 0.0/434.5 kB ? eta -:--:--
#    --- ------------------------------------ 41.0/434.5 kB 1.9 MB/s eta 0:00:01
#    --------------- ------------------------ 163.8/434.5 kB 2.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 256.0/434.5 kB 1.7 MB/s eta 0:00:01
#    --------------------------------- ------ 368.6/434.5 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 378.9/434.5 kB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  430.1/434.5 kB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 434.5/434.5 kB 1.5 MB/s eta 0:00:00
# Downloading tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#     --------------------------------------- 0.1/5.5 MB 2.6 MB/s eta 0:00:03
#    - -------------------------------------- 0.1/5.5 MB 2.1 MB/s eta 0:00:03
#    - -------------------------------------- 0.2/5.5 MB 1.7 MB/s eta 0:00:04
#    -- ------------------------------------- 0.3/5.5 MB 1.7 MB/s eta 0:00:03
#    --- ------------------------------------ 0.5/5.5 MB 1.9 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.6/5.5 MB 1.9 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.6/5.5 MB 1.9 MB/s eta 0:00:03
#    ----- ---------------------------------- 0.8/5.5 MB 1.9 MB/s eta 0:00:03
#    ------ --------------------------------- 0.9/5.5 MB 2.0 MB/s eta 0:00:03
#    ------- -------------------------------- 1.0/5.5 MB 2.1 MB/s eta 0:00:03
#    ------- -------------------------------- 1.1/5.5 MB 2.0 MB/s eta 0:00:03
#    -------- ------------------------------- 1.2/5.5 MB 2.0 MB/s eta 0:00:03
#    --------- ------------------------------ 1.3/5.5 MB 2.1 MB/s eta 0:00:03
#    --------- ------------------------------ 1.3/5.5 MB 2.0 MB/s eta 0:00:03
#    ---------- ----------------------------- 1.5/5.5 MB 2.0 MB/s eta 0:00:03
#    ----------- ---------------------------- 1.6/5.5 MB 2.0 MB/s eta 0:00:03
#    ----------- ---------------------------- 1.6/5.5 MB 1.9 MB/s eta 0:00:03
#    ------------ --------------------------- 1.7/5.5 MB 1.9 MB/s eta 0:00:02
#    ------------ --------------------------- 1.8/5.5 MB 1.9 MB/s eta 0:00:02
#    ------------- -------------------------- 1.9/5.5 MB 1.9 MB/s eta 0:00:02
#    -------------- ------------------------- 1.9/5.5 MB 1.9 MB/s eta 0:00:02
#    -------------- ------------------------- 2.0/5.5 MB 1.9 MB/s eta 0:00:02
#    --------------- ------------------------ 2.1/5.5 MB 1.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 2.2/5.5 MB 1.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 2.3/5.5 MB 1.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 2.4/5.5 MB 1.8 MB/s eta 0:00:02
#    ------------------ --------------------- 2.5/5.5 MB 1.8 MB/s eta 0:00:02
#    ------------------ --------------------- 2.6/5.5 MB 1.8 MB/s eta 0:00:02
#    ------------------ --------------------- 2.6/5.5 MB 1.8 MB/s eta 0:00:02
#    -------------------- ------------------- 2.8/5.5 MB 1.8 MB/s eta 0:00:02
#    --------------------- ------------------ 2.9/5.5 MB 1.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 3.0/5.5 MB 1.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 3.2/5.5 MB 1.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 3.3/5.5 MB 1.8 MB/s eta 0:00:02
#    ------------------------ --------------- 3.4/5.5 MB 1.9 MB/s eta 0:00:02
#    ------------------------- -------------- 3.5/5.5 MB 1.9 MB/s eta 0:00:02
#    -------------------------- ------------- 3.6/5.5 MB 1.9 MB/s eta 0:00:02
#    -------------------------- ------------- 3.7/5.5 MB 1.9 MB/s eta 0:00:01
#    --------------------------- ------------ 3.8/5.5 MB 1.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 3.9/5.5 MB 1.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.0/5.5 MB 1.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.1/5.5 MB 1.9 MB/s eta 0:00:01
#    ------------------------------ --------- 4.2/5.5 MB 1.9 MB/s eta 0:00:01
#    ------------------------------- -------- 4.3/5.5 MB 1.9 MB/s eta 0:00:01
#    -------------------------------- ------- 4.4/5.5 MB 2.0 MB/s eta 0:00:01
#    -------------------------------- ------- 4.5/5.5 MB 2.0 MB/s eta 0:00:01
#    --------------------------------- ------ 4.6/5.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.7/5.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.8/5.5 MB 2.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.9/5.5 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 5.0/5.5 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 5.1/5.5 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 5.3/5.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  5.4/5.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  5.5/5.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  5.5/5.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  5.5/5.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  5.5/5.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  5.5/5.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 1.9 MB/s eta 0:00:00
# Downloading tensorflow_io_gcs_filesystem-0.31.0-cp311-cp311-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.1/1.5 MB 2.4 MB/s eta 0:00:01
#    -------- ------------------------------- 0.3/1.5 MB 2.5 MB/s eta 0:00:01
#    ------------ --------------------------- 0.5/1.5 MB 2.7 MB/s eta 0:00:01
#    ------------------- -------------------- 0.7/1.5 MB 2.7 MB/s eta 0:00:01
#    ------------------------ --------------- 0.9/1.5 MB 2.7 MB/s eta 0:00:01
#    --------------------------- ------------ 1.0/1.5 MB 2.7 MB/s eta 0:00:01
#    ------------------------------- -------- 1.2/1.5 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------ --- 1.4/1.5 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  1.5/1.5 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 2.4 MB/s eta 0:00:00
# Downloading termcolor-2.5.0-py3-none-any.whl (7.8 kB)
# Downloading wrapt-1.17.0-cp311-cp311-win_amd64.whl (38 kB)
# Downloading Markdown-3.7-py3-none-any.whl (106 kB)
#    ---------------------------------------- 0.0/106.3 kB ? eta -:--:--
#    -------------------------- ------------- 71.7/106.3 kB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 106.3/106.3 kB 1.0 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#    ---------------------------------------- 0.0/224.5 kB ? eta -:--:--
#    ------------------------- -------------- 143.4/224.5 kB 8.3 MB/s eta 0:00:01
#    -------------------------------------- - 215.0/224.5 kB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 224.5/224.5 kB 1.9 MB/s eta 0:00:00
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
#    ---------------------------------------- 0.0/72.5 kB ? eta -:--:--
#    ---------------------------------------  71.7/72.5 kB ? eta -:--:--
#    ---------------------------------------- 72.5/72.5 kB 1.3 MB/s eta 0:00:00
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.13.1-cp311-cp311-win_amd64.whl (292 kB)
#    ---------------------------------------- 0.0/292.2 kB ? eta -:--:--
#    ------------------------------ --------- 225.3/292.2 kB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  286.7/292.2 kB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 292.2/292.2 kB 3.0 MB/s eta 0:00:00
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
#    ---------------------------------------- 0.0/242.4 kB ? eta -:--:--
#    ----------------------- ---------------- 143.4/242.4 kB 4.3 MB/s eta 0:00:01
#    -------------------------------------- - 235.5/242.4 kB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 242.4/242.4 kB 2.1 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ---------------------------------------- 0.0/87.5 kB ? eta -:--:--
#    ------------------------------------- -- 81.9/87.5 kB ? eta -:--:--
#    ---------------------------------------- 87.5/87.5 kB 1.7 MB/s eta 0:00:00
# Using cached MarkupSafe-3.0.2-cp311-cp311-win_amd64.whl (15 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, wheel, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, protobuf, optree, opt-einsum, numpy, mdurl, MarkupSafe, markdown, grpcio, google-pasta, gast, absl-py, werkzeug, ml-dtypes, markdown-it-py, h5py, astunparse, tensorboard, rich, keras, tensorflow-intel, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.0
#     Uninstalling numpy-2.2.0:
#       Successfully uninstalled numpy-2.2.0
# Successfully installed MarkupSafe-3.0.2 absl-py-2.1.0 astunparse-1.6.3 flatbuffers-24.12.23 gast-0.6.0 google-pasta-0.2.0 grpcio-1.69.0 h5py-3.12.1 keras-3.8.0 libclang-18.1.1 markdown-3.7 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.4.1 namex-0.0.8 numpy-2.0.2 opt-einsum-3.4.0 optree-0.13.1 protobuf-5.29.3 rich-13.9.4 tensorboard-2.18.0 tensorboard-data-server-0.7.2 tensorflow-2.18.0 tensorflow-intel-2.18.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.5.0 werkzeug-3.1.3 wheel-0.45.1 wrapt-1.17.0
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       6 from tensorflow.keras import layers
#       7 import numpy as np
# ----> 8 import matplotlib.pyplot as plt
#       9 import os
#      11 # Set random seed for reproducibility
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
local_folder_path = r"C:\Users\MTechS_h\Desktop\Mini Project\ecg_data"

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
pip install tensorflow-gpu
# Out:
# Requirement already satisfied: tensorflow-gpu in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (2.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (24.3.25)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (3.11.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: packaging in c:\users\mtechs_h\appdata\roaming\python\python310\site-packages (from tensorflow-gpu) (24.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\mtechs_h\appdata\roaming\python\python310\site-packages (from tensorflow-gpu) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\mtechs_h\appdata\roaming\python\python310\site-packages (from tensorflow-gpu) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (1.63.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (2.10.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.29.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow-gpu) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow-gpu) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\mtechs_h\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow-gpu) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf

# Set memory growth on GPU before any operations
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    try:
        tf.config.experimental.set_memory_growth(physical_devices[0], True)
    except RuntimeError as e:
        print(e)

# %%
import tensorflow as tf
import numpy as np
import os
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# Constants
IMG_HEIGHT, IMG_WIDTH = 64, 64
BUFFER_SIZE = 60000
BATCH_SIZE = 32  # Reduce batch size to fit in memory
EPOCHS = 50
NOISE_DIM = 100
NUM_EXAMPLES_TO_GENERATE = 16
SEED = 42

# Set random seeds for reproducibility
np.random.seed(SEED)
tf.random.set_seed(SEED)

# Function to load and preprocess data
def load_and_preprocess_data(local_folder_path):
    print(f"Loading dataset from: {local_folder_path}")
    
    # List files in the dataset directory
    files_in_directory = os.listdir(local_folder_path)
    print(f"Files in directory: {files_in_directory}")
    
    images = []
    
    # Loop through each file in the directory and check if it is a valid PNG image
    for img_name in files_in_directory:
        img_path = os.path.join(local_folder_path, img_name)
        
        try:
            # Load and preprocess the image (resize and normalize)
            img = image.load_img(img_path, target_size=(IMG_HEIGHT, IMG_WIDTH))
            img = image.img_to_array(img)
            img = (img - 127.5) / 127.5  # Normalize to [-1, 1]
            images.append(img)
        except Exception as e:
            print(f"Skipping file {img_name} due to error: {e}")
    
    if not images:
        raise ValueError("No valid images found in the dataset.")
    
    return np.array(images)

# Function to build the generator model
def build_generator():
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(8*8*256, use_bias=False, input_shape=(NOISE_DIM,)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.LeakyReLU(),

        tf.keras.layers.Reshape((8, 8, 256)),

        tf.keras.layers.Conv2DTranspose(128, (5, 5), strides=(2, 2), padding='same', use_bias=False),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.LeakyReLU(),

        tf.keras.layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.LeakyReLU(),

        tf.keras.layers.Conv2DTranspose(3, (5, 5), strides=(2, 2), padding='same', use_bias=False, activation='tanh')
    ])
    return model

# Function to build the discriminator model
def build_discriminator():
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(64, (5, 5), strides=(2, 2), padding='same', input_shape=[IMG_HEIGHT, IMG_WIDTH, 3]),
        tf.keras.layers.LeakyReLU(),
        tf.keras.layers.Dropout(0.3),

        tf.keras.layers.Conv2D(128, (5, 5), strides=(2, 2), padding='same'),
        tf.keras.layers.LeakyReLU(),
        tf.keras.layers.Dropout(0.3),

        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(1)
    ])
    return model

# Define loss functions
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    return real_loss + fake_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# Optimizers
generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

# Checkpoints
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=build_generator(),
                                 discriminator=build_discriminator())

# Function to generate and save images
def generate_and_save_images(model, epoch, test_input):
    predictions = model(test_input, training=False)
    fig = plt.figure(figsize=(4, 4))

    for i in range(predictions.shape[0]):
        plt.subplot(4, 4, i+1)
        plt.imshow((predictions[i] * 127.5 + 127.5).numpy().astype("uint8"))
        plt.axis('off')

    plt.savefig(f'image_at_epoch_{epoch:04d}.png')
    plt.show()

# Training step function
@tf.function
def train_step(images):
    noise = tf.random.normal([BATCH_SIZE, NOISE_DIM])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = build_generator()(noise, training=True)

        real_output = build_discriminator()(images, training=True)
        fake_output = build_discriminator()(generated_images, training=True)

        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, build_generator().trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, build_discriminator().trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, build_generator().trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, build_discriminator().trainable_variables))

    return gen_loss, disc_loss

# Training function
def train(dataset, epochs):
    for epoch in range(epochs):
        print(f"Epoch {epoch+1}/{epochs}")
        for image_batch in dataset:
            gen_loss, disc_loss = train_step(image_batch)

        # Save the model every 5 epochs
        if (epoch + 1) % 5 == 0:
            checkpoint.save(file_prefix=checkpoint_prefix)

        # Generate and save images
        generate_and_save_images(build_generator(), epoch + 1, seed)

        print(f"Generator loss: {gen_loss}, Discriminator loss: {disc_loss}")

# Main function to load the data, create dataset, and start training
def main():
    local_folder_path = r"C:\Users\MTechS_h\Desktop\Mini Project\ecg_data\ECG_Image_data"

    # Load the dataset from the folder
    dataset = load_and_preprocess_data(local_folder_path)
    print(f"Loaded dataset with shape: {dataset.shape}")

    # Create TensorFlow Dataset
    dataset = tf.data.Dataset.from_tensor_slices(dataset).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

    # Set device to CPU to avoid GPU-related issues
    with tf.device('/CPU:0'):
        # Start the training process
        train(dataset, EPOCHS)

if __name__ == "__main__":
    main()
